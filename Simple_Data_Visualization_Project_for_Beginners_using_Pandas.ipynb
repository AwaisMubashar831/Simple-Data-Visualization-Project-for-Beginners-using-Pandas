# %% [markdown]
# # **Simple Data Visualization Project for Beginners using Pandas**

# %% [markdown]
# **This project is designed for beginners to learn how to perform data visualization using Pandas and Matplotlib. We'll work with a simple dataset and create easy-to-understand visualizations.**

# %% [markdown]
# # **Project Overview**
# We'll use a small sales dataset containing information about sales transactions. The dataset includes:
#
#
# *   Date of sale
# *   Product sold
# *   Quantity sold
# *   Price per unit
# * Total Sales (Quantity × Price)
#
# We'll visualize:
#
# * Total Sales Over Time (Line Plot)
#
# * Sales by Product (Bar Chart)
# * Price Distribution (Histogram)
# * Quantity vs. Total Sales (Scatter Plot)

# %% [markdown]
# #**Step 1: Import Required Libraries**

# %% [markdown]
# **We'll use a small sales dataset containing information about sales transactions. The dataset includes:**
#
# First, we import the necessary libraries:
#
#
# *   pandas for data manipulation
#
# * matplotlib.pyplot for visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # **Step 2: Create a Simple Dataset**
#
# Since this is for beginners, we'll manually create a small dataset.

# %%
# Create a dictionary with sample sales data
data = {
    "Date": ["2023-01-01", "2023-01-02", "2023-01-03", "2023-01-04", "2023-01-05"],
    "Product": ["Apple", "Banana", "Apple", "Orange", "Banana"],
    "Quantity": [5, 3, 7, 2, 4],
    "Price": [1.5, 0.5, 1.5, 2.0, 0.5]
}

# Convert the dictionary into a Pandas DataFrame
df = pd.DataFrame(data)

# Calculate Total Sales (Quantity * Price)
df["Total_Sales"] = df["Quantity"] * df["Price"]

# Display the DataFrame
print("Sample Sales Data:")
print(df)
# Out:
# Sample Sales Data:
#          Date Product  Quantity  Price  Total_Sales
# 0  2023-01-01   Apple         5    1.5          7.5
# 1  2023-01-02  Banana         3    0.5          1.5
# 2  2023-01-03   Apple         7    1.5         10.5
# 3  2023-01-04  Orange         2    2.0          4.0
# 4  2023-01-05  Banana         4    0.5          2.0

# %% [markdown]
# #**Step 3: Visualizations**
#
# **1.Line Plot - Total Sales Over Time**
#
# We'll plot how sales change over time.

# %%
# Convert 'Date' to datetime format for better plotting
df['Date'] = pd.to_datetime(df['Date'])

# Create a line plot
plt.figure(figsize=(8, 4))
plt.plot(df['Date'], df['Total_Sales'], marker='o', linestyle='-', color='blue')

# Add titles and labels
plt.title("Total Sales Over Time")
plt.xlabel("Date")
plt.ylabel("Total Sales ($)")
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# **Explanation:**
#
#
# *   Lplt.plot() creates a line graph.
#
# * marker='o' adds dots at each data point.
#
# * plt.grid(True) adds grid lines for better readability.

# %% [markdown]
# #**2. Bar Chart - Sales by Product**
# We'll compare total sales for each product.

# %%
# Group data by Product and sum the Total_Sales
product_sales = df.groupby('Product')['Total_Sales'].sum()

# Create a bar chart
plt.figure(figsize=(8, 4))
product_sales.plot(kind='bar', color=['red', 'yellow', 'orange'])

# Add titles and labels
plt.title("Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Total Sales ($)")
plt.xticks(rotation=0)  # Keep product names horizontal

# Show the plot
plt.show()

# %% [markdown]
# **Explanation:**
#
#
# *   groupby() groups data by 'Product' and sums 'Total_Sales'.
#
# *  kind='bar' creates a bar chart.

# %% [markdown]
# #**3. Histogram - Price Distribution**
# We'll see how prices are distributed.

# %%
plt.figure(figsize=(8, 4))
plt.hist(df['Price'], bins=5, color='green', edgecolor='black')

# Add titles and labels
plt.title("Distribution of Prices")
plt.xlabel("Price ($)")
plt.ylabel("Frequency")

# Show the plot
plt.show()

# %% [markdown]
# #**Explanation:**
#
#
# *   plt.hist() creates a histogram.
#
# * bins=5 divides data into 5 ranges.m

# %% [markdown]
# #**4. Scatter Plot - Quantity vs. Total Sales**
# We'll check if higher quantities lead to higher sales.

# %%
plt.figure(figsize=(8, 4))
plt.scatter(df['Quantity'], df['Total_Sales'], color='purple')

# Add titles and labels
plt.title("Quantity vs. Total Sales")
plt.xlabel("Quantity Sold")
plt.ylabel("Total Sales ($)")

# Show the plot
plt.show()

# %% [markdown]
# **Explanation:**
#
#
# *   plt.scatter() creates a scatter plot.
#
# *  Helps identify trends (e.g., more quantity → higher sales).
